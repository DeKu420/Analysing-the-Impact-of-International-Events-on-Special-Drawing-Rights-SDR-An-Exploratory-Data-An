# %%
import pandas as pd

# %% [markdown]
# ## Timeline Data

# %%
timeline = pd.read_excel('RawData/timeline_data.xlsx')
timeline
# Out:
#      Year              Date                                        Description
# 0    2010        January 12  A 7.0 magnitude earthquake in Haiti kills 230,...
# 1    2010       February 18                         2010 Nigerien coup d'état.
# 2    2010          March 29                        2010 Moscow Metro bombings.
# 3    2010          April 10  The President of Poland, Lech Kaczyński, is am...
# 4    2010          April 20  The largest oil spill in US history occurs in ...
# ..    ...               ...                                                ...
# 173  2021         October 6  The World Health Organization endorses the fir...
# 174  2021       November 16  Russia draws international condemnation follow...
# 175  2021       November 30  Barbados becomes a republic on its 55th annive...
# 176  2021        December 9  A truck crash in Chiapas, Mexico, kills 55 mig...
# 177  2021  December 16 – 18  Typhoon Rai lashes into Visayas and Mindanao, ...
#
# [178 rows x 3 columns]

# %% [markdown]
# ## Financial Data
# #### As the unit of currency is different for all countries, to ensure all currencies is on a similar/same scale we use SDR values.

# %%
data = pd.read_csv('RawData/cleaned_exchange_rate.csv', index_col=0)
data
# Out:
#            Algeria  Australia  Botswana    Brazil    Brunei    Canada  \
# Date
# 1/4/16    0.006710   0.520544  0.064140  0.184561  0.506341  0.515910
# 1/5/16    0.006723   0.522630  0.064223  0.179481  0.508786  0.518022
# 1/6/16    0.006723   0.516299  0.063713  0.180693  0.506380  0.514650
# 1/7/16    0.006725   0.508623  0.063135  0.179236  0.503045  0.513742
# 1/8/16    0.006717   0.510064  0.063352  0.178473  0.503849  0.510471
# ...            ...        ...       ...       ...       ...       ...
# 12/17/21  0.005148   0.512476  0.060994  0.125551  0.523769  0.556632
# 12/20/21  0.005150   0.509316  0.060897  0.125583  0.523903  0.553576
# 12/21/21  0.005151   0.509225  0.061210  0.124794  0.524090  0.553808
# 12/22/21  0.005145   0.510355  0.060888  0.125096  0.524203  0.556148
# 12/23/21       NaN   0.515149  0.061232  0.125561  0.524784       NaN
#
#              Chile     China  Colombia  Czech Republic  ...  Singapore  \
# Date                                                    ...
# 1/4/16    0.001015  0.110659  0.000229        0.029066  ...   0.506341
# 1/5/16    0.001011  0.111183  0.000226        0.028827  ...   0.508786
# 1/6/16    0.001014  0.110623  0.000226        0.028768  ...   0.506380
# 1/7/16    0.001001  0.109555  0.000222        0.029042  ...   0.503045
# 1/8/16    0.001001  0.109636  0.000220        0.029042  ...   0.503849
# ...            ...       ...       ...             ...  ...        ...
# 12/17/21  0.000842  0.112212  0.000179        0.032066  ...   0.523769
# 12/20/21  0.000846  0.112324  0.000179        0.032014  ...   0.523903
# 12/21/21  0.000829  0.112359  0.000179        0.032035  ...   0.524090
# 12/22/21  0.000824  0.112259  0.000179        0.032027  ...   0.524203
# 12/23/21  0.000825  0.112158  0.000179        0.032216  ...   0.524784
#
#           South Africa    Sweden  Switzerland  Thailand  Trinidadian  \
# Date
# 1/4/16        0.046369  0.085704     0.721685  0.019929     0.112887
# 1/5/16        0.045834  0.085161     0.717691  0.020065     0.112887
# 1/6/16        0.045834  0.084140     0.718581  0.020014     0.112829
# 1/7/16        0.044869  0.084140     0.722156  0.019900     0.112381
# 1/8/16        0.045201  0.085012     0.722946  0.019936     0.112734
# ...                ...       ...          ...       ...          ...
# 12/17/21      0.045137  0.079100     0.777566  0.021421     0.105541
# 12/20/21      0.045197  0.078342     0.775660  0.021391     0.105821
# 12/21/21      0.045170  0.078409     0.776261  0.021255     0.105660
# 12/22/21      0.045058  0.078187     0.775299  0.021188     0.105660
# 12/23/21      0.047028  0.078374     0.776454  0.021269          NaN
#
#             U.A.E.      U.K.      U.S.   Uruguay
# Date
# 1/4/16    0.196236  1.064440  0.720675  0.024011
# 1/5/16    0.197377  1.063310  0.724868  0.024011
# 1/6/16    0.197368  1.062820  0.724833  0.023704
# 1/7/16    0.196698  1.052210  0.722373  0.023704
# 1/8/16    0.196697  1.054800  0.722368  0.023704
# ...            ...       ...       ...       ...
# 12/17/21  0.195082  0.950087  0.715050  0.016118
# 12/20/21  0.195082  0.945806  0.716438  0.016159
# 12/21/21  0.194937  0.948326  0.715907  0.016121
# 12/22/21  0.194822  0.952668  0.715485  0.016121
# 12/23/21  0.194552  0.959850  0.714493  0.016092
#
# [1485 rows x 39 columns]

# %%
data.isnull().sum()
# Out:
# Algeria           1
# Australia         0
# Botswana          0
# Brazil            0
# Brunei            0
# Canada            1
# Chile             0
# China             0
# Colombia          0
# Czech Republic    0
# Denmark           0
# EUR               0
# India             0
# Israel            0
# Japan             0
# Korean            0
# Kuwait            0
# Malaysia          0
# Mauritius         0
# Mexico            0
# New Zealand       0
# Norway            0
# Oman              0
# Peru              1
# Philippines       0
# Poland            0
# Qatar             0
# Russia            0
# Saudi Arabia      1
# Singapore         0
# South Africa      0
# Sweden            0
# Switzerland       0
# Thailand          0
# Trinidadian       1
# U.A.E.            0
# U.K.              0
# U.S.              0
# Uruguay           0
# dtype: int64

# %%
# Filter Methods: These methods assess the relevance of features based on statistical measures and are computationally efficient.
# Correlation Analysis: Compute pairwise correlations between features and remove highly correlated features to reduce redundancy.
# Variance Thresholding: Remove features with low variance, as they might not provide much information.

# %%
columns = data.columns
correlation_matrix = data[columns].corr()
correlation_matrix
# Out:
#                  Algeria  Australia  Botswana    Brazil    Brunei    Canada  \
# Algeria         1.000000   0.342581  0.618340  0.895926  0.027727 -0.148533
# Australia       0.342581   1.000000  0.563456  0.564856  0.044198  0.526395
# Botswana        0.618340   0.563456  1.000000  0.837592  0.380042  0.243956
# Brazil          0.895926   0.564856  0.837592  1.000000  0.202294  0.124549
# Brunei          0.027727   0.044198  0.380042  0.202294  1.000000  0.330376
# Canada         -0.148533   0.526395  0.243956  0.124549  0.330376  1.000000
# Chile           0.704479   0.657443  0.877022  0.879778  0.205675  0.156038
# China          -0.006304   0.476546  0.112075  0.109094 -0.128344  0.251185
# Colombia        0.837978   0.570394  0.855699  0.939439  0.225932  0.079935
# Czech Republic -0.575713   0.009620  0.127805 -0.285928  0.248062  0.330991
# Denmark        -0.587152   0.180068  0.007414 -0.322218 -0.035261  0.235800
# 12/21/21      0.045170  0.078409     0.776261  0.021255     0.105660
# 12/22/21      0.045058  0.078187     0.775299  0.021188     0.105660
# 12/23/21      0.047028  0.078374     0.776454  0.021269          NaN
#
#             U.A.E.      U.K.      U.S.   Uruguay
# Date
# 1/4/16    0.196236  1.064440  0.720675  0.024011
# 1/5/16    0.197377  1.063310  0.724868  0.024011
# 1/6/16    0.197368  1.062820  0.724833  0.023704
# 1/7/16    0.196698  1.052210  0.722373  0.023704
# 1/8/16    0.196697  1.054800  0.722368  0.023704
# ...            ...       ...       ...       ...
# 12/17/21  0.195082  0.950087  0.715050  0.016118
# 12/20/21  0.195082  0.945806  0.716438  0.016159
# 12/21/21  0.194937  0.948326  0.715907  0.016121
# 12/22/21  0.194822  0.952668  0.715485  0.016121
# 12/23/21  0.194552  0.959850  0.714493  0.016092
#
# [1485 rows x 39 columns]

# %%
from sklearn.feature_selection import VarianceThreshold

threshold_value = 0.0000001
selector = VarianceThreshold(threshold=threshold_value)

selector.fit(data)
selected_features = selector.get_support(indices=True)
selected_columns = data.columns[selected_features]
data_selected = selector.transform(data)
data_selected_df = pd.DataFrame(data_selected, columns=selected_columns)

print("Selected Features:")
# print(data_selected_df.head())
data_selected_df.head()
# Out:
# Selected Features:
#     Algeria  Australia  Botswana    Brazil    Brunei    Canada     China  \
# 0  0.006710   0.520544  0.064140  0.184561  0.506341  0.515910  0.110659
# 1  0.006723   0.522630  0.064223  0.179481  0.508786  0.518022  0.111183
# 2  0.006723   0.516299  0.063713  0.180693  0.506380  0.514650  0.110623
# 3  0.006725   0.508623  0.063135  0.179236  0.503045  0.513742  0.109555
# 4  0.006717   0.510064  0.063352  0.178473  0.503849  0.510471  0.109636
#
#    Czech Republic   Denmark       EUR  ...  Singapore  South Africa    Sweden  \
# 0        0.029066  0.105253  0.785392  ...   0.506341      0.046369  0.085704
# 1        0.028827  0.104409  0.778943  ...   0.508786      0.045834  0.085161
# 2        0.028768  0.104368  0.778616  ...   0.506380      0.045834  0.084140
# 3        0.029042  0.105244  0.785075  ...   0.503045      0.044869  0.084140
# 4        0.029042  0.105173  0.784564  ...   0.503849      0.045201  0.085012
#
#    Switzerland  Thailand  Trinidadian    U.A.E.     U.K.      U.S.   Uruguay
# 0     0.721685  0.019929     0.112887  0.196236  1.06444  0.720675  0.024011
# 1     0.717691  0.020065     0.112887  0.197377  1.06331  0.724868  0.024011
# 2     0.718581  0.020014     0.112829  0.197368  1.06282  0.724833  0.023704
# 3     0.722156  0.019900     0.112381  0.196698  1.05221  0.722373  0.023704
# 4     0.722946  0.019936     0.112734  0.196697  1.05480  0.722368  0.023704
#
# [5 rows x 35 columns]

# %%
data_selected_df.columns
# Out:
# Index(['Algeria', 'Australia', 'Botswana', 'Brazil', 'Brunei', 'Canada',
#        'China', 'Czech Republic', 'Denmark', 'EUR', 'India', 'Israel',
#        'Kuwait', 'Malaysia', 'Mauritius', 'Mexico', 'New Zealand', 'Norway',
#        'Oman', 'Peru', 'Philippines', 'Poland', 'Qatar', 'Russia',
#        'Saudi Arabia', 'Singapore', 'South Africa', 'Sweden', 'Switzerland',
#        'Thailand', 'Trinidadian', 'U.A.E.', 'U.K.', 'U.S.', 'Uruguay'],
#       dtype='object')

# %% [markdown]
# ## ------------------------------------Time Series Data filtering------------------------------------

# %%
oldData = pd.read_excel('RawData/timeline_data.xlsx')
newData = pd.read_excel('RawData/newTimeLine.xlsx')
newData
# Out:
#                                                 Events
# 0    7.0 magnitude earthquake in Haiti - Date: Janu...
# 1    2010 Nigerien coup d'état - Date: February 18,...
# 2    2010 Moscow Metro bombings - Date: March 29, 2...
# 3    Plane crash in Smolensk, Russia - Date: April ...
# 4    Deepwater Horizon oil spill - Date: April 20, ...
# ..                                                 ...
# 173  The World Health Organization endorses the fir...
# 174  Russia draws international condemnation follow...
# 175  Barbados becomes a republic on its 55th annive...
# 176  A truck crash in Chiapas, Mexico, kills 55 mig...
# 177  Typhoon Rai lashes into Visayas and Mindanao, ...
#
# [178 rows x 1 columns]

# %%
# months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
ls = []
for i in newData['Events']:
    print(i.split("Date")[1].split("Countr")[0])
# Out:
# : January 12, 2010.
# : February 18, 2010.
# : March 29, 2010.
# : April 10, 2010.
# : April 20, 2010.
# : May 31, 2010.
# : July 22, 2010.
# : November 23, 2010.
# : February 22, 2011.
# : March 11, 2011.
# : May 2, 2011.
# : July 9, 2011.
# : July 22, 2011.
# s: August 6-10, 2011.
# : October 20, 2011.
# s: December 2010 - ongoing.
# : May 7, 2012.
# : July 20, 2012.
# : September 11–12, 2012.
# : October 14, 2012.
# : October 29–30, 2012.
# : November 6, 2012.
# : November 15, 2012.
# : December 8, 2012.
# : December 3, 2012.
# : December 14, 2012.
# : February 15, 2013.
# : February 28, 2013.
# : March 5, 2013.
# : April 24, 2013.
# : May 22, 2013.
# : July 1, 2013.
# : July 3, 2013.
# : July 22, 2013.
# : August 21, 2013.
# : September 9–28, 2013.
# : September 17, 2013.
# : October 15, 2013.
# : November 2–11, 2013.
# : November 21, 2013.
# : December 5, 2013.
# s: November 2013 - ongoing.
# : March 8, 2014.
# : April 16, 2014.
# : May 22, 2014.
# : June 19, 2014.
# : August 9, 2014.
# : November 12, 2014.
# : December 16, 2014.
# : January 1, 2015.
# : January 3–7, 2015.
# : April 2, 2015.
# : April 19, 2015.
# : May 13, 2015.
# : July 14, 2015.
# : September 30, 2015.
# : December 12, 2015.
# : September 14, 2015.
# : March 9–15, 2016.
# : March 20–22, 2016.
# : April 3, 2016.
# : May 9, 2016.
# : June 1, 2016.
# : June 12, 2016.
# : June 23, 2016.
# : July 4, 2016.
# : September 4, 2016.
# : November 4, 2016.
# : November 8, 2016.
# : January 20, 2017.
# : January 21, 2017.
# : February 13, 2017.
# : May 13, 2017.
# : May 22, 2017.
# : June 2, 2017.
# : August 11–12, 2017.
# s: September 8 and September 19, 2017.
# : October 1, 2017.
# : October 14, 2017.
# : October 19, 2017.
# : November 5, 2017.
# : March 24, 2018.
# : June 12, 2018.
# s: June 23 - July 10, 2018.
# : June 24, 2018.
# : October 2, 2018.
# : January 3, 2019.
# : January 21, 2019.
# : June 28, 2019.
# : April 15, 2019.
# : April 30, 2019.
# : August 5, 2019.
# : October 18, 2019.
# : December 18, 2019.
# : December 20, 2019.
# : January 2020.
# : January 3, 2020.
# : January 8, 2020.
# : February 5, 2020.
# : January 31, 2020.
# : February 9, 2020.
# : May 25, 2020.
# : May 30, 2020.
# : June 16, 2020.
# : June 30, 2020.
# : July 9, 2020.
# : July 10, 2020.
# : July 28, 2020.
# : July 30, 2020.
# : August 4, 2020.
# : August 18, 2020.
# : August 25, 2020. Region: Africa.
# : August 26, 2020.
# : September 16, 2020.
# s: September 27 - November 10, 2020.
# : October 15, 2020.
# : October 20, 2020.
# : October 22, 2020.
# : November 14, 2020.
# : November 13, 2020.
# s: November 3, 2020 - January 6, 2021.
# : November 4, 2020.
# : November 15, 2020. Region: Asia-Pacific.
# : November 19, 2020.
# : November 27, 2020.
# : November 30, 2020.
# : December 1, 2020.
# : December 2, 2020.
# : December 8, 2020.
# : December 18, 2020.
# : December 21, 2020.
# : January 1, 2021. Region: Africa.
# : January 6, 2021.
# : January 11, 2021.
# : January 15, 2021.
# : January 13, 2021 (impeachment); February 13, 2021 (acquittal).
# : January 20, 2021.
# : January 22, 2021.
# s: February 13–17, 2021. Region: North America (primarily affecting the United States, especially Texas).
# : February 18, 2021. Planet: Mars.
# : February 22, 2021.
# : March 6, 2021.
# : March 18, 2021.
# : March 20, 2021.
# : March 25, 2021.
# s: March 23–29, 2021.
# : April 9, 2021.
# : April 11, 2021.
# : April 13, 2021.
# : April 15, 2021.
# : April 20, 2021.
# : April 24, 2021.
# : April 28, 2021.
# : May 6, 2021.
# : May 23, 2021.
# : June 7, 2021. Planet: Jupiter.
# : June 13, 2021.
# : June 17, 2021.
# : June 24, 2021.
# : July 4, 2021.
# : July 7, 2021.
# : July 18, 2021.
# : July 20, 2021.
# : July 28, 2021.
# : August 9, 2021.
# : August 14, 2021.
# : August 15, 2021.
# : August 30, 2021.
# : September 7, 2021.
# : September 15, 2021.
# : September 15, 2021.
# : September 16, 2021.
# : October 3, 2021.
# : October 6, 2021.
# : November 15, 2021.
# : November 30, 2021.
# : December 8, 2021.
# : December 16, 2021.

# %%
import re

pattern = r'\b(?:Country|Countries|Region|Regions|Planet)\b'
date = r'\b(?:Date|Dates)\b'
date_pattern = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s(?:\d{1,2},?\s)?(?:\d{4}|\d{4}\s?-\s?ongoing|\d{4}\s?-\s?present|\d{4}\s?-\s?\d{4}|January|February|March|April|May|June|July|August|September|October|November|December\s\d{4})'

ls = []
for i in newData['Events']:
    ls.append(re.split(f'{date}: ', i)[1])

country = []
date_Country = []
for j in ls:
    date_Country.append(re.findall(date_pattern, j))
    country.append(re.split(f'{pattern}: ', j)[1][:-1])

for i in range(len(date_Country)):
    if(len(date_Country[i]) > 0):
        date_Country[i] = date_Country[i][0]
    else:
        date_Country[i] = ""

# %%
pd.DataFrame({"Country": country, "Date": date_Country})
# Out:
#                                 Country               Date
# 0                                 Haiti   January 12, 2010
# 1                                 Niger  February 18, 2010
# 2                                Russia     March 29, 2010
# 3                                Russia     April 10, 2010
# 4        United States (Gulf of Mexico)     April 20, 2010
# ..                                  ...                ...
# 173                       International    October 6, 2021
# 174                              Russia  November 15, 2021
# 175                            Barbados  November 30, 2021
# 176                              Mexico   December 8, 2021
# 177  Philippines (Visayas and Mindanao)  December 16, 2021
#
# [178 rows x 2 columns]

# %%
oldData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         178 non-null    int64
#  1   Date         178 non-null    object
#  2   Description  178 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.3+ KB

# %%
for i in range(177):
    if(i < len(country)-1):
        continue
    else:
        country.append("")

# %%
len(country)
# Out:
# 178

# %%
country
# Out:
# ['Haiti',
#  'Niger',
#  'Russia',
#  'Russia',
#  'United States (Gulf of Mexico)',
#  'International waters (Gaza Strip)',
#  'Colombia and Venezuela',
#  'South Korea (Yeonpyeong Island)',
#  'New Zealand (Christchurch)',
#  'Japan',
#  'Pakistan',
#  'South Sudan',
#  'Norway',
#  'United Kingdom',
#  'Libya',
#  'Tunisia, Egypt, Libya, Yemen, Bahrain, and others',
#  'Russia',
#  'United States (Aurora, Colorado)',
#  'Libya',
#  'United States (jump took place over New Mexico)',
#  'United States, Caribbean',
#  'United States',
#  'China',
#  'Qatar (conference held in Doha)',
#  'Philippines',
#  'United States (Newtown, Connecticut)',
#  'Russia',
#  'Vatican City',
#  'Venezuela',
#  'Bangladesh',
#  'United Kingdom (Woolwich)',
#  'Croatia',
#  'Egypt',
#  'United Kingdom',
#  'Syria',
#  'Philippines',
#  'International release',
#  'Philippines',
#  'Philippines, Vietnam',
#  'Ukraine',
#  'South Africa',
#  'Ukraine, Russia',
#  'International waters (disappeared en route from Kuala Lumpur to Beijing)',
#  'South Korea',
#  'Thailand',
#  'Spain',
#  'United States (Ferguson, Missouri)',
#  'International (comet 67P/Churyumov–Gerasimenko)',
#  'Pakistan',
#  'Russia, Kazakhstan, Belarus, Armenia, Kyrgyzstan',
#  'Nigeria',
#  'Kenya',
#  'United States (Baltimore, Maryland)',
#  'Philippines',
#  'Austria (negotiated in Vienna)',
#  'Syria',
#  'France (conference held in Le Bourget)',
#  'United States (LIGO observatory)',
#  'South Korea',
#  'Cuba',
#  'International (leak originated from Panama)',
#  'Philippines',
#  'Switzerland, Italy',
#  'United States',
#  'United Kingdom',
#  'United States (Jupiter orbit)',
#  'Vatican City',
#  'International (agreement took effect)',
#  'United States',
#  'United States',
#  'United States (and worldwide)',
#  'Malaysia',
#  'Portugal',
#  'United Kingdom',
#  'Philippines',
#  'United States',
#  'Mexico',
#  'United States',
#  'Somalia',
#  'International (object passed through solar system)',
#  'United States',
#  'United States (and worldwide)',
#  'Singapore, North Korea',
#  'Thailand',
#  'Saudi Arabia',
#  'Turkey (assassination in Saudi consulate)',
#  'China',
#  'Philippines',
#  'Philippines',
#  'France',
#  'Japan',
#  'India',
#  'International Space Station',
#  'United States',
#  'United States',
#  'Australia',
#  'Iraq (Baghdad International Airport)',
#  'Iran',
#  'United States',
#  'United Kingdom',
#  'United States (Los Angeles, California)',
#  'United States (Minneapolis, Minnesota) and worldwide',
#  'United States (Kennedy Space Center, Florida)',
#  'North Korea (Kaesong)',
#  'China (Hong Kong)',
#  'Bulgaria',
#  'Turkey (Istanbul)',
#  'Malaysia',
#  'United States (Cape Canaveral, Florida)',
#  'Lebanon (Beirut)',
#  'Lebanon',
#  'Africa',
#  'United States',
#  'Venezuela',
#  'Armenia, Azerbaijan',
#  'Kyrgyzstan',
#  'United States',
#  'Switzerland',
#  'Falkland Islands (United Kingdom)',
#  'Senegal, Spain',
#  'United States',
#  'Ethiopia',
#  'Asia-Pacific',
#  'Australia',
#  'Iran',
#  'United Kingdom',
#  'United States (Puerto Rico)',
#  'International',
#  'Nepal, China',
#  'International',
#  'International',
#  'Africa',
#  'United States (Washington, D.C.)',
#  'North Korea',
#  'France',
#  'United States',
#  'United States',
#  'International',
#  'North America (primarily affecting the United States, especially Texas)',
#  'Mars',
#  'Democratic Republic of the Congo',
#  'Iraq',
#  'Spain',
#  'Turkey',
#  'Venezuela, Colombia',
#  'Egypt',
#  'United Kingdom',
#  'United States',
#  'Japan',
#  'International',
#  'Chad',
#  'Indonesia',
#  'Kyrgyzstan, Tajikistan',
#  'Israel',
#  'Belarus',
#  'Jupiter',
#  'Israel',
#  'United States',
#  'United States',
#  'Philippines',
#  'Haiti',
#  'International',
#  'United States',
#  'International',
#  'International',
#  'Haiti',
#  'Afghanistan',
#  'International',
#  'El Salvador',
#  'North Korea, South Korea',
#  'Australia, United Kingdom, United States',
#  'United States',
#  'International',
#  'International',
#  'Russia',
#  'Barbados',
#  'Mexico',
#  'Philippines (Visayas and Mindanao)']

# %%
oldData['FullDate'] = [pd.to_datetime(f"{date}, {year}") if "–" not in f"{date}, {year}" else "" for date,year in zip(oldData['Date'], oldData['Year'])]

# %%
oldData['Country'] = country

# %%
oldData
# Out:
#      Year              Date  \
# 0    2010        January 12
# 1    2010       February 18
# 2    2010          March 29
# 3    2010          April 10
# 4    2010          April 20
# ..    ...               ...
# 173  2021         October 6
# 174  2021       November 16
# 175  2021       November 30
# 176  2021        December 9
# 177  2021  December 16 – 18
#
#                                            Description             FullDate  \
# 0    A 7.0 magnitude earthquake in Haiti kills 230,...  2010-01-12 00:00:00
# 1                           2010 Nigerien coup d'état.  2010-02-18 00:00:00
# 2                          2010 Moscow Metro bombings.  2010-03-29 00:00:00
# 3    The President of Poland, Lech Kaczyński, is am...  2010-04-10 00:00:00
# 4    The largest oil spill in US history occurs in ...  2010-04-20 00:00:00
# ..                                                 ...                  ...
# 173  The World Health Organization endorses the fir...  2021-10-06 00:00:00
# 174  Russia draws international condemnation follow...  2021-11-16 00:00:00
# 175  Barbados becomes a republic on its 55th annive...  2021-11-30 00:00:00
# 176  A truck crash in Chiapas, Mexico, kills 55 mig...  2021-12-09 00:00:00
# 177  Typhoon Rai lashes into Visayas and Mindanao, ...
#
#                                 Country
# 0                                 Haiti
# 1                                 Niger
# 2                                Russia
# 3                                Russia
# 4        United States (Gulf of Mexico)
# ..                                  ...
# 173                       International
# 174                              Russia
# 175                            Barbados
# 176                              Mexico
# 177  Philippines (Visayas and Mindanao)
#
# [178 rows x 5 columns]

# %%
oldData.to_csv('RawData/updatedTimeline.csv', index=False)

# %%
Unique_Countries = []
for i in oldData['Country'].unique():
    if i.find('(') != -1:
        Unique_Countries.append(i[:i.find('(')].strip())

Unique_Countries = list(set(Unique_Countries))
Unique_Countries
# Out:
# ['North Korea',
#  'Turkey',
#  'United States',
#  'International',
#  'China',
#  'South Korea',
#  'Lebanon',
#  'Austria',
#  'Philippines',
#  'Qatar',
#  'International waters',
#  'North America',
#  'France',
#  'Iraq',
#  'United Kingdom',
#  'New Zealand',
#  'Falkland Islands']

# %%
countries = {"Austria": "EUR", "France": "EUR", "North America": "U.S.", "South Korea": "Korean", "United Kingdom": "U.K.", "United States": "U.S.", "Vatican City": "EUR", "Ukraine": "EUR", "Spain": "EUR", "El Salvador": "U.S.", "Portugal": "EUR", "Germany": "EUR", "Europe": "EUR"}
    
for index, row in oldData.iterrows():
    i = row['Country']
    if i.find('(') != -1:
        i = i[:i.find('(')].strip()
    if i in countries:
        oldData.at[index, 'Country'] = countries[i]
    else:
        if "," in i:
            sub_countries = i.split(",")
            for idx, val in enumerate(sub_countries):
                strip_val = val.strip()
                if strip_val in countries:
                    sub_countries[idx] = countries[strip_val]
                else:
                    sub_countries[idx] = strip_val
            oldData.at[index, 'Country'] = ",".join(sub_countries)
        else:
            oldData.at[index, 'Country'] = i

oldData
# Out:
#      Year              Date  \
# 0    2010        January 12
# 1    2010       February 18
# 2    2010          March 29
# 3    2010          April 10
# 4    2010          April 20
# ..    ...               ...
# 173  2021         October 6
# 174  2021       November 16
# 175  2021       November 30
# 176  2021        December 9
# 177  2021  December 16 – 18
#
#                                            Description             FullDate  \
# 0    A 7.0 magnitude earthquake in Haiti kills 230,...  2010-01-12 00:00:00
# 1                           2010 Nigerien coup d'état.  2010-02-18 00:00:00
# 2                          2010 Moscow Metro bombings.  2010-03-29 00:00:00
# 3    The President of Poland, Lech Kaczyński, is am...  2010-04-10 00:00:00
# 4    The largest oil spill in US history occurs in ...  2010-04-20 00:00:00
# ..                                                 ...                  ...
# 173  The World Health Organization endorses the fir...  2021-10-06 00:00:00
# 174  Russia draws international condemnation follow...  2021-11-16 00:00:00
# 175  Barbados becomes a republic on its 55th annive...  2021-11-30 00:00:00
# 176  A truck crash in Chiapas, Mexico, kills 55 mig...  2021-12-09 00:00:00
# 177  Typhoon Rai lashes into Visayas and Mindanao, ...
#
#            Country
# 0            Haiti
# 1            Niger
# 2           Russia
# 3           Russia
# 4             U.S.
# ..             ...
# 173  International
# 174         Russia
# 175       Barbados
# 176         Mexico
# 177    Philippines
#
# [178 rows x 5 columns]

# %%
oldData['Country'].unique()
# Out:
# array(['Haiti', 'Niger', 'Russia', 'U.S.', 'International waters',
#        'Colombia and Venezuela', 'Korean', 'New Zealand', 'Japan',
#        'Pakistan', 'South Sudan', 'Norway', 'U.K.', 'Libya',
#        'Tunisia,Egypt,Libya,Yemen,Bahrain,and others', 'U.S.,Caribbean',
#        'China', 'Qatar', 'Philippines', 'EUR', 'Venezuela', 'Bangladesh',
#        'Croatia', 'Egypt', 'Syria', 'International release',
#        'Philippines,Vietnam', 'South Africa', 'EUR,Russia', 'Thailand',
#        'International', 'Russia,Kazakhstan,Belarus,Armenia,Kyrgyzstan',
#        'Nigeria', 'Kenya', 'Cuba', 'Switzerland,Italy', 'Malaysia',
#        'Mexico', 'Somalia', 'Singapore,North Korea', 'Saudi Arabia',
#        'Turkey', 'India', 'International Space Station', 'Australia',
#        'Iraq', 'Iran', 'North Korea', 'Bulgaria', 'Lebanon', 'Africa',
#        'Armenia,Azerbaijan', 'Kyrgyzstan', 'Switzerland',
#        'Falkland Islands', 'Senegal,EUR', 'Ethiopia', 'Asia-Pacific',
#        'Nepal,China', 'Mars', 'Democratic Republic of the Congo',
#        'Venezuela,Colombia', 'Chad', 'Indonesia', 'Kyrgyzstan,Tajikistan',
#        'Israel', 'Belarus', 'Jupiter', 'Afghanistan',
#        'North Korea,Korean', 'Australia,U.K.,U.S.', 'Barbados'],
#       dtype=object)

# %%
event_Countries = []

for i in oldData['Country'].unique():
    if "," in i:
        for j in i.split(","):
            event_Countries.append(j)
    else:
        event_Countries.append(i)
event_Countries = list(set(event_Countries))
print(event_Countries)
# Out:
# ['Niger', 'Pakistan', 'Iran', 'Kazakhstan', 'Africa', 'U.S.', 'Philippines', 'International Space Station', 'Mars', 'Korean', 'North Korea', 'Libya', 'China', 'Afghanistan', 'Azerbaijan', 'Italy', 'Jupiter', 'Yemen', 'Colombia and Venezuela', 'South Sudan', 'Senegal', 'Belarus', 'Iraq', 'Kenya', 'Democratic Republic of the Congo', 'Bulgaria', 'Tunisia', 'Caribbean', 'Vietnam', 'International release', 'South Africa', 'Asia-Pacific', 'Syria', 'International', 'Kyrgyzstan', 'Israel', 'Bahrain', 'Bangladesh', 'Croatia', 'EUR', 'Venezuela', 'Falkland Islands', 'Cuba', 'Switzerland', 'Ethiopia', 'Chad', 'Haiti', 'Barbados', 'Nigeria', 'U.K.', 'Somalia', 'Singapore', 'New Zealand', 'Saudi Arabia', 'Thailand', 'Turkey', 'Malaysia', 'Mexico', 'Japan', 'Egypt', 'and others', 'Lebanon', 'Qatar', 'Indonesia', 'India', 'Australia', 'Russia', 'Nepal', 'Colombia', 'International waters', 'Tajikistan', 'Armenia', 'Norway']

# %%
oldData.to_csv('RawData/updatedTimeline.csv', index=False)

# %% [markdown]
# ### ------------------------------------Time Series Filtering Ended------------------------------------

# %%
data_selected_df
# Out:
#        Algeria  Australia  Botswana    Brazil    Brunei    Canada     China  \
# 0     0.006710   0.520544  0.064140  0.184561  0.506341  0.515910  0.110659
# 1     0.006723   0.522630  0.064223  0.179481  0.508786  0.518022  0.111183
# 2     0.006723   0.516299  0.063713  0.180693  0.506380  0.514650  0.110623
# 3     0.006725   0.508623  0.063135  0.179236  0.503045  0.513742  0.109555
# 4     0.006717   0.510064  0.063352  0.178473  0.503849  0.510471  0.109636
# ...        ...        ...       ...       ...       ...       ...       ...
# 1480  0.005148   0.512476  0.060994  0.125551  0.523769  0.556632  0.112212
# 1481  0.005150   0.509316  0.060897  0.125583  0.523903  0.553576  0.112324
# 1482  0.005151   0.509225  0.061210  0.124794  0.524090  0.553808  0.112359
# 1483  0.005145   0.510355  0.060888  0.125096  0.524203  0.556148  0.112259
# 1484       NaN   0.515149  0.061232  0.125561  0.524784       NaN  0.112158
#
#       Czech Republic   Denmark       EUR  ...  Singapore  South Africa  \
# 0           0.029066  0.105253  0.785392  ...   0.506341      0.046369
# 1           0.028827  0.104409  0.778943  ...   0.508786      0.045834
# 2           0.028768  0.104368  0.778616  ...   0.506380      0.045834
# 3           0.029042  0.105244  0.785075  ...   0.503045      0.044869
# 4           0.029042  0.105173  0.784564  ...   0.503849      0.045201
# ...              ...       ...       ...  ...        ...           ...
# 1480        0.032066  0.108943  0.810152  ...   0.523769      0.045137
# 1481        0.032014  0.108607  0.807641  ...   0.523903      0.045197
# 1482        0.032035  0.108741  0.808617  ...   0.524090      0.045170
# 1483        0.032027  0.108735  0.808570  ...   0.524203      0.045058
# 1484        0.032216  0.108670  0.808092  ...   0.524784      0.047028
#
#         Sweden  Switzerland  Thailand  Trinidadian    U.A.E.      U.K.  \
# 0     0.085704     0.721685  0.019929     0.112887  0.196236  1.064440
# 1     0.085161     0.717691  0.020065     0.112887  0.197377  1.063310
# 2     0.084140     0.718581  0.020014     0.112829  0.197368  1.062820
# 3     0.084140     0.722156  0.019900     0.112381  0.196698  1.052210
# 4     0.085012     0.722946  0.019936     0.112734  0.196697  1.054800
# ...        ...          ...       ...          ...       ...       ...
# 1480  0.079100     0.777566  0.021421     0.105541  0.195082  0.950087
# 1481  0.078342     0.775660  0.021391     0.105821  0.195082  0.945806
# 1482  0.078409     0.776261  0.021255     0.105660  0.194937  0.948326
# 1483  0.078187     0.775299  0.021188     0.105660  0.194822  0.952668
# 1484  0.078374     0.776454  0.021269          NaN  0.194552  0.959850
#
#           U.S.   Uruguay
# 0     0.720675  0.024011
# 1     0.724868  0.024011
# 2     0.724833  0.023704
# 3     0.722373  0.023704
# 4     0.722368  0.023704
# ...        ...       ...
# 1480  0.715050  0.016118
# 1481  0.716438  0.016159
# 1482  0.715907  0.016121
# 1483  0.715485  0.016121
# 1484  0.714493  0.016092
#
# [1485 rows x 35 columns]

# %%
final_selected_features = []

for i in data_selected_df:
    if i in event_Countries:
        final_selected_features.append(i)
print(len(final_selected_features))
# Out:
# 19

# %%
print(final_selected_features)
# Out:
# ['Australia', 'China', 'EUR', 'India', 'Israel', 'Malaysia', 'Mexico', 'New Zealand', 'Norway', 'Philippines', 'Qatar', 'Russia', 'Saudi Arabia', 'Singapore', 'South Africa', 'Switzerland', 'Thailand', 'U.K.', 'U.S.']

# %%
final_df = data[final_selected_features]
final_df
